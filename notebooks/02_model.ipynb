# %%
import pandas as pd

df = pd.read_csv("../data/raw/paysim-dataset.csv")

df.groupby("type")["amount"].agg(["count", "sum", "mean"]).round(2)
df.groupby("type")["isFraud"].mean().round(4)
# Out:
# type
# CASH_IN     0.0000
# CASH_OUT    0.0018
# DEBIT       0.0000
# PAYMENT     0.0000
# TRANSFER    0.0077
# Name: isFraud, dtype: float64
